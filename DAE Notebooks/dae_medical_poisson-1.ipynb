# %%
import numpy as np
import tensorflow as tf
import pickle
from skimage.metrics import structural_similarity
from scipy.ndimage import median_filter
import matplotlib.pyplot as plt

# %%
physical_devices = tf.config.list_physical_devices('GPU')
tf.config.experimental.set_memory_growth(physical_devices[0], True)

# %%
with open('Data/train_data_aug.pickle', "rb") as file:
    train_data = pickle.load(file)

# %%
with open('Data/test_data.pickle', "rb") as file:
    test_data = pickle.load(file)

# %%
d = 128

# %%
X_train = train_data.reshape((train_data.shape[0], d, d, 1))
X_test = test_data.reshape((test_data.shape[0], d, d, 1))
X_train.shape, X_test.shape
# Out:
# ((1600, 128, 128, 1), (80, 128, 128, 1))

# %% [markdown]
# ## ADD NOISE (GAUSSIAN OR POISSON)

# %%
noise_factor = 0.2
X_train_noisy = X_train + noise_factor * tf.random.poisson(shape=X_train.shape, lam=1) 
X_test_noisy = X_test + noise_factor * tf.random.poisson(shape=X_test.shape, lam=1)

X_train_noisy = tf.clip_by_value(X_train_noisy, clip_value_min=0., clip_value_max=1.)
X_test_noisy = tf.clip_by_value(X_test_noisy, clip_value_min=0., clip_value_max=1.)
X_train_noisy.shape, X_test_noisy.shape
# Out:
# (TensorShape([1600, 128, 128, 1]), TensorShape([80, 128, 128, 1]))

# %%
plt.imshow(X_train[0], cmap='gray')

# %%
plt.imshow(X_train_noisy[0], cmap='gray')

# %% [markdown]
# ## CREATE AUTO-ENCODER ARCHITECTURE

# %%
lam = tf.keras.regularizers.l1(l=0)
input_img = tf.keras.layers.Input(shape=(d, d, 1))
x = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', strides=2, padding='same', kernel_regularizer=lam)(input_img)
x = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', strides=2, padding='same', kernel_regularizer=lam)(x)
# x = tf.keras.layers.Conv2D(16, (3, 3), activation='relu', strides=2, padding='same', kernel_regularizer=lam)(x)
# x = tf.keras.layers.Conv2D(8, (3, 3), activation='relu', strides=2, padding='same', kernel_regularizer=lam)(x)

# x = tf.keras.layers.Conv2DTranspose(8, kernel_size=3, activation='relu', strides=2, padding='same', kernel_regularizer=lam)(x)
# x = tf.keras.layers.Conv2DTranspose(16, kernel_size=3, activation='relu', strides=2, padding='same', kernel_regularizer=lam)(x)
x = tf.keras.layers.Conv2DTranspose(32, kernel_size=3, activation='relu', strides=2, padding='same', kernel_regularizer=lam)(x)
x = tf.keras.layers.Conv2DTranspose(64, kernel_size=3, activation='relu', strides=2, padding='same', kernel_regularizer=lam)(x)

x = tf.keras.layers.Conv2D(32, kernel_size=(3, 3), activation='sigmoid', padding='same', kernel_regularizer=lam)(x)
x = tf.keras.layers.Conv2D(16, kernel_size=(3, 3), activation='sigmoid', padding='same', kernel_regularizer=lam)(x)
x = tf.keras.layers.Conv2D(8, kernel_size=(3, 3), activation='sigmoid', padding='same', kernel_regularizer=lam)(x)
# x = tf.keras.layers.Conv2D(4, kernel_size=(3, 3), activation='sigmoid', padding='same', kernel_regularizer=lam)(x)
decoder_output = tf.keras.layers.Conv2D(1, kernel_size=(3, 3), activation='sigmoid', padding='same', kernel_regularizer=lam)(x)
autoencoder = tf.keras.Model(input_img, decoder_output)

# %%
autoencoder.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 128, 128, 1)]     0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 64, 64, 64)        640
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 32)        18464
# _________________________________________________________________
# conv2d_transpose (Conv2DTran (None, 64, 64, 32)        9248
# _________________________________________________________________
# conv2d_transpose_1 (Conv2DTr (None, 128, 128, 64)      18496
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 128, 128, 32)      18464
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 128, 128, 16)      4624
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 128, 128, 8)       1160
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 128, 128, 1)       73
# =================================================================
# Total params: 71,169
# Trainable params: 71,169
# Non-trainable params: 0
# _________________________________________________________________

# %%
autoencoder.compile(optimizer='adam', loss='mse')

# %% [markdown]
# ## TRAIN THE MODEL

# %%
history = autoencoder.fit(X_train_noisy, X_train, epochs=150, batch_size=64, validation_split=0.2)
# Out:
# Epoch 1/150
# 20/20 [==============================] - 13s 303ms/step - loss: 0.0938 - val_loss: 0.0869
# Epoch 2/150
# 20/20 [==============================] - 5s 246ms/step - loss: 0.0834 - val_loss: 0.0636
# Epoch 3/150
# 20/20 [==============================] - 5s 250ms/step - loss: 0.0455 - val_loss: 0.0182
# Epoch 4/150
# 20/20 [==============================] - 5s 253ms/step - loss: 0.0164 - val_loss: 0.0114
# Epoch 5/150
# 20/20 [==============================] - 5s 259ms/step - loss: 0.0110 - val_loss: 0.0094
# Epoch 6/150
# 20/20 [==============================] - 5s 253ms/step - loss: 0.0091 - val_loss: 0.0078
# Epoch 7/150
# 20/20 [==============================] - 5s 267ms/step - loss: 0.0083 - val_loss: 0.0070
# Epoch 8/150
# 20/20 [==============================] - 5s 275ms/step - loss: 0.0070 - val_loss: 0.0064
# Epoch 9/150
# 20/20 [==============================] - 5s 266ms/step - loss: 0.0064 - val_loss: 0.0059
# Epoch 10/150
# 20/20 [==============================] - 5s 251ms/step - loss: 0.0060 - val_loss: 0.0065
# Epoch 11/150
# 20/20 [==============================] - 5s 260ms/step - loss: 0.0060 - val_loss: 0.0054
# Epoch 12/150
# 20/20 [==============================] - 5s 266ms/step - loss: 0.0054 - val_loss: 0.0050
# Epoch 13/150
# 20/20 [==============================] - 5s 256ms/step - loss: 0.0051 - val_loss: 0.0050
# Epoch 14/150
# 20/20 [==============================] - 5s 265ms/step - loss: 0.0050 - val_loss: 0.0048
# Epoch 15/150
# 20/20 [==============================] - 5s 263ms/step - loss: 0.0049 - val_loss: 0.0046
# Epoch 16/150
# 20/20 [==============================] - 5s 254ms/step - loss: 0.0047 - val_loss: 0.0047
# Epoch 17/150
# 20/20 [==============================] - 5s 255ms/step - loss: 0.0046 - val_loss: 0.0044
# Epoch 18/150
# 20/20 [==============================] - 5s 254ms/step - loss: 0.0045 - val_loss: 0.0044
# Epoch 19/150
# 20/20 [==============================] - 5s 261ms/step - loss: 0.0044 - val_loss: 0.0042
# Epoch 20/150
# 20/20 [==============================] - 5s 256ms/step - loss: 0.0043 - val_loss: 0.0041
# Epoch 21/150
# 20/20 [==============================] - 5s 262ms/step - loss: 0.0043 - val_loss: 0.0041
# Epoch 22/150
# 20/20 [==============================] - 5s 250ms/step - loss: 0.0042 - val_loss: 0.0041
# Epoch 23/150
# 20/20 [==============================] - 5s 263ms/step - loss: 0.0041 - val_loss: 0.0041
# Epoch 24/150
# 20/20 [==============================] - 5s 263ms/step - loss: 0.0040 - val_loss: 0.0039
# Epoch 25/150
# 20/20 [==============================] - 5s 261ms/step - loss: 0.0040 - val_loss: 0.0039
# Epoch 26/150
# 20/20 [==============================] - 5s 277ms/step - loss: 0.0039 - val_loss: 0.0039
# Epoch 27/150
# 20/20 [==============================] - 5s 270ms/step - loss: 0.0039 - val_loss: 0.0038
# Epoch 28/150
# 20/20 [==============================] - 5s 259ms/step - loss: 0.0038 - val_loss: 0.0037
# Epoch 29/150
# 20/20 [==============================] - 5s 265ms/step - loss: 0.0037 - val_loss: 0.0037
# Epoch 30/150
# 20/20 [==============================] - 5s 256ms/step - loss: 0.0038 - val_loss: 0.0037
# Epoch 31/150
# 20/20 [==============================] - 5s 251ms/step - loss: 0.0037 - val_loss: 0.0036
# Epoch 32/150
# 20/20 [==============================] - 5s 252ms/step - loss: 0.0036 - val_loss: 0.0035
# Epoch 33/150
# 20/20 [==============================] - 5s 251ms/step - loss: 0.0036 - val_loss: 0.0035
# Epoch 34/150
# 20/20 [==============================] - 5s 251ms/step - loss: 0.0036 - val_loss: 0.0035
# Epoch 35/150
# 20/20 [==============================] - 5s 253ms/step - loss: 0.0035 - val_loss: 0.0035
# Epoch 36/150
# 20/20 [==============================] - 5s 252ms/step - loss: 0.0035 - val_loss: 0.0034
# Epoch 37/150
# 20/20 [==============================] - 5s 251ms/step - loss: 0.0035 - val_loss: 0.0034
# Epoch 38/150
# 20/20 [==============================] - 5s 265ms/step - loss: 0.0035 - val_loss: 0.0035
# Epoch 39/150
# 20/20 [==============================] - 5s 270ms/step - loss: 0.0035 - val_loss: 0.0033
# Epoch 40/150
# 20/20 [==============================] - 5s 269ms/step - loss: 0.0034 - val_loss: 0.0032
# Epoch 41/150
# 20/20 [==============================] - 5s 269ms/step - loss: 0.0033 - val_loss: 0.0033
# Epoch 42/150
# 20/20 [==============================] - 5s 252ms/step - loss: 0.0034 - val_loss: 0.0032
# Epoch 43/150
# 20/20 [==============================] - 5s 251ms/step - loss: 0.0033 - val_loss: 0.0033
# Epoch 44/150
# 20/20 [==============================] - 5s 250ms/step - loss: 0.0033 - val_loss: 0.0032
# Epoch 45/150
# 20/20 [==============================] - 5s 251ms/step - loss: 0.0032 - val_loss: 0.0035
# Epoch 46/150
# 20/20 [==============================] - 5s 253ms/step - loss: 0.0033 - val_loss: 0.0031
# Epoch 47/150
# 20/20 [==============================] - 5s 252ms/step - loss: 0.0031 - val_loss: 0.0031
# Epoch 48/150
# 20/20 [==============================] - 5s 252ms/step - loss: 0.0034 - val_loss: 0.0032
# Epoch 49/150
# 20/20 [==============================] - 5s 250ms/step - loss: 0.0032 - val_loss: 0.0030
# Epoch 50/150
# 20/20 [==============================] - 5s 253ms/step - loss: 0.0031 - val_loss: 0.0030
# Epoch 51/150
# 20/20 [==============================] - 5s 250ms/step - loss: 0.0031 - val_loss: 0.0030
# Epoch 52/150
# 20/20 [==============================] - 5s 255ms/step - loss: 0.0031 - val_loss: 0.0030
# Epoch 53/150
# 20/20 [==============================] - 5s 252ms/step - loss: 0.0031 - val_loss: 0.0029
# Epoch 54/150
# 20/20 [==============================] - 5s 250ms/step - loss: 0.0033 - val_loss: 0.0032
# Epoch 55/150
# 20/20 [==============================] - 5s 253ms/step - loss: 0.0031 - val_loss: 0.0030
# Epoch 56/150
# 20/20 [==============================] - 5s 251ms/step - loss: 0.0030 - val_loss: 0.0029
# Epoch 57/150
# 20/20 [==============================] - 5s 251ms/step - loss: 0.0029 - val_loss: 0.0029
# Epoch 58/150
# 20/20 [==============================] - 5s 252ms/step - loss: 0.0029 - val_loss: 0.0028
# Epoch 59/150
# 20/20 [==============================] - 5s 252ms/step - loss: 0.0029 - val_loss: 0.0028
# Epoch 60/150
# 20/20 [==============================] - 5s 250ms/step - loss: 0.0030 - val_loss: 0.0029
# Epoch 61/150
# 20/20 [==============================] - 5s 250ms/step - loss: 0.0029 - val_loss: 0.0028
# Epoch 62/150
# 20/20 [==============================] - 5s 251ms/step - loss: 0.0029 - val_loss: 0.0035
# Epoch 63/150
# 20/20 [==============================] - 5s 250ms/step - loss: 0.0033 - val_loss: 0.0028
# Epoch 64/150
# 20/20 [==============================] - 5s 256ms/step - loss: 0.0029 - val_loss: 0.0029
# Epoch 65/150
# 20/20 [==============================] - 5s 262ms/step - loss: 0.0028 - val_loss: 0.0028
# Epoch 66/150
# 20/20 [==============================] - 5s 251ms/step - loss: 0.0028 - val_loss: 0.0027
# Epoch 67/150
# 20/20 [==============================] - 5s 255ms/step - loss: 0.0028 - val_loss: 0.0027
# Epoch 68/150
# 20/20 [==============================] - 5s 259ms/step - loss: 0.0027 - val_loss: 0.0027
# Epoch 69/150
# 20/20 [==============================] - 5s 253ms/step - loss: 0.0028 - val_loss: 0.0027
# Epoch 70/150
# 20/20 [==============================] - 5s 262ms/step - loss: 0.0029 - val_loss: 0.0027
# Epoch 71/150
# 20/20 [==============================] - 5s 263ms/step - loss: 0.0027 - val_loss: 0.0027
# Epoch 72/150
# 20/20 [==============================] - 5s 255ms/step - loss: 0.0027 - val_loss: 0.0027
# Epoch 73/150
# 20/20 [==============================] - 5s 261ms/step - loss: 0.0027 - val_loss: 0.0027
# Epoch 74/150
# 20/20 [==============================] - 5s 263ms/step - loss: 0.0028 - val_loss: 0.0026
# Epoch 75/150
# 20/20 [==============================] - 5s 255ms/step - loss: 0.0027 - val_loss: 0.0026
# Epoch 76/150
# 20/20 [==============================] - 5s 261ms/step - loss: 0.0026 - val_loss: 0.0027
# Epoch 77/150
# 20/20 [==============================] - 5s 253ms/step - loss: 0.0027 - val_loss: 0.0026
# Epoch 78/150
# 20/20 [==============================] - 5s 252ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 79/150
# 20/20 [==============================] - 5s 250ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 80/150
# 20/20 [==============================] - 6s 278ms/step - loss: 0.0026 - val_loss: 0.0025
# Epoch 81/150
# 20/20 [==============================] - 5s 250ms/step - loss: 0.0026 - val_loss: 0.0025
# Epoch 82/150
# 20/20 [==============================] - 5s 251ms/step - loss: 0.0026 - val_loss: 0.0027
# Epoch 83/150
# 20/20 [==============================] - 5s 259ms/step - loss: 0.0026 - val_loss: 0.0025
# Epoch 84/150
# 20/20 [==============================] - 5s 258ms/step - loss: 0.0025 - val_loss: 0.0026
# Epoch 85/150
# 20/20 [==============================] - 5s 253ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 86/150
# 20/20 [==============================] - 5s 271ms/step - loss: 0.0025 - val_loss: 0.0024
# Epoch 87/150
# 20/20 [==============================] - 5s 269ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 88/150
# 20/20 [==============================] - 5s 266ms/step - loss: 0.0025 - val_loss: 0.0024
# Epoch 89/150
# 20/20 [==============================] - 5s 255ms/step - loss: 0.0025 - val_loss: 0.0024
# Epoch 90/150
# 20/20 [==============================] - 5s 254ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 91/150
# 20/20 [==============================] - 5s 272ms/step - loss: 0.0025 - val_loss: 0.0024
# Epoch 92/150
# 20/20 [==============================] - 5s 263ms/step - loss: 0.0025 - val_loss: 0.0024
# Epoch 93/150
# 20/20 [==============================] - 5s 253ms/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 94/150
# 20/20 [==============================] - 5s 252ms/step - loss: 0.0025 - val_loss: 0.0024
# Epoch 95/150
# 20/20 [==============================] - 5s 254ms/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 96/150
# 20/20 [==============================] - 5s 253ms/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 97/150
# 20/20 [==============================] - 5s 265ms/step - loss: 0.0025 - val_loss: 0.0025
# Epoch 98/150
# 20/20 [==============================] - 5s 255ms/step - loss: 0.0024 - val_loss: 0.0023
# Epoch 99/150
# 20/20 [==============================] - 5s 252ms/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 100/150
# 20/20 [==============================] - 5s 254ms/step - loss: 0.0024 - val_loss: 0.0023
# Epoch 101/150
# 20/20 [==============================] - 5s 252ms/step - loss: 0.0024 - val_loss: 0.0024
# Epoch 102/150
# 20/20 [==============================] - 5s 255ms/step - loss: 0.0024 - val_loss: 0.0023
# Epoch 103/150
# 20/20 [==============================] - 5s 253ms/step - loss: 0.0024 - val_loss: 0.0023
# Epoch 104/150
# 20/20 [==============================] - 5s 254ms/step - loss: 0.0023 - val_loss: 0.0023
# Epoch 105/150
# 20/20 [==============================] - 5s 254ms/step - loss: 0.0023 - val_loss: 0.0024
# Epoch 106/150
# 20/20 [==============================] - 5s 252ms/step - loss: 0.0024 - val_loss: 0.0023
# Epoch 107/150
# 20/20 [==============================] - 5s 252ms/step - loss: 0.0024 - val_loss: 0.0023
# Epoch 108/150
# 20/20 [==============================] - 5s 253ms/step - loss: 0.0023 - val_loss: 0.0024
# Epoch 109/150
# 20/20 [==============================] - 5s 254ms/step - loss: 0.0024 - val_loss: 0.0023
# Epoch 110/150
# 20/20 [==============================] - 5s 252ms/step - loss: 0.0023 - val_loss: 0.0023
# Epoch 111/150
# 20/20 [==============================] - 5s 257ms/step - loss: 0.0023 - val_loss: 0.0022
# Epoch 112/150
# 20/20 [==============================] - 5s 252ms/step - loss: 0.0023 - val_loss: 0.0022
# Epoch 113/150
# 20/20 [==============================] - 5s 254ms/step - loss: 0.0023 - val_loss: 0.0024
# Epoch 114/150
# 20/20 [==============================] - 5s 252ms/step - loss: 0.0024 - val_loss: 0.0023
# Epoch 115/150
# 20/20 [==============================] - 5s 253ms/step - loss: 0.0023 - val_loss: 0.0022
# Epoch 116/150
# 20/20 [==============================] - 5s 252ms/step - loss: 0.0023 - val_loss: 0.0023
# Epoch 117/150
# 20/20 [==============================] - 5s 252ms/step - loss: 0.0023 - val_loss: 0.0022
# Epoch 118/150
# 20/20 [==============================] - 5s 252ms/step - loss: 0.0023 - val_loss: 0.0024
# Epoch 119/150
# 20/20 [==============================] - 5s 252ms/step - loss: 0.0023 - val_loss: 0.0022
# Epoch 120/150
# 20/20 [==============================] - 5s 252ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 121/150
# 20/20 [==============================] - 5s 252ms/step - loss: 0.0023 - val_loss: 0.0022
# Epoch 122/150
# 20/20 [==============================] - 5s 252ms/step - loss: 0.0023 - val_loss: 0.0022
# Epoch 123/150
# 20/20 [==============================] - 5s 252ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 124/150
# 20/20 [==============================] - 5s 252ms/step - loss: 0.0023 - val_loss: 0.0022
# Epoch 125/150
# 20/20 [==============================] - 5s 252ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 126/150
# 20/20 [==============================] - 5s 255ms/step - loss: 0.0022 - val_loss: 0.0027
# Epoch 127/150
# 20/20 [==============================] - 5s 253ms/step - loss: 0.0025 - val_loss: 0.0022
# Epoch 128/150
# 20/20 [==============================] - 5s 262ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 129/150
# 20/20 [==============================] - 5s 255ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 130/150
# 20/20 [==============================] - 5s 265ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 131/150
# 20/20 [==============================] - 5s 258ms/step - loss: 0.0022 - val_loss: 0.0021
# Epoch 132/150
# 20/20 [==============================] - 5s 253ms/step - loss: 0.0022 - val_loss: 0.0021
# Epoch 133/150
# 20/20 [==============================] - 5s 254ms/step - loss: 0.0022 - val_loss: 0.0021
# Epoch 134/150
# 20/20 [==============================] - 5s 253ms/step - loss: 0.0023 - val_loss: 0.0022
# Epoch 135/150
# 20/20 [==============================] - 5s 255ms/step - loss: 0.0022 - val_loss: 0.0021
# Epoch 136/150
# 20/20 [==============================] - 5s 253ms/step - loss: 0.0022 - val_loss: 0.0021
# Epoch 137/150
# 20/20 [==============================] - 5s 252ms/step - loss: 0.0022 - val_loss: 0.0021
# Epoch 138/150
# 20/20 [==============================] - 5s 262ms/step - loss: 0.0022 - val_loss: 0.0021
# Epoch 139/150
# 20/20 [==============================] - 5s 258ms/step - loss: 0.0022 - val_loss: 0.0021
# Epoch 140/150
# 20/20 [==============================] - 5s 253ms/step - loss: 0.0021 - val_loss: 0.0023
# Epoch 141/150
# 20/20 [==============================] - 5s 254ms/step - loss: 0.0022 - val_loss: 0.0021
# Epoch 142/150
# 20/20 [==============================] - 5s 253ms/step - loss: 0.0021 - val_loss: 0.0021
# Epoch 143/150
# 20/20 [==============================] - 5s 253ms/step - loss: 0.0022 - val_loss: 0.0021
# Epoch 144/150
# 20/20 [==============================] - 5s 253ms/step - loss: 0.0021 - val_loss: 0.0021
# Epoch 145/150
# 20/20 [==============================] - 5s 256ms/step - loss: 0.0021 - val_loss: 0.0023
# Epoch 146/150
# 20/20 [==============================] - 5s 269ms/step - loss: 0.0022 - val_loss: 0.0021
# Epoch 147/150
# 20/20 [==============================] - 5s 252ms/step - loss: 0.0021 - val_loss: 0.0021
# Epoch 148/150
# 20/20 [==============================] - 5s 262ms/step - loss: 0.0022 - val_loss: 0.0021
# Epoch 149/150
# 20/20 [==============================] - 5s 260ms/step - loss: 0.0021 - val_loss: 0.0021
# Epoch 150/150
# 20/20 [==============================] - 5s 269ms/step - loss: 0.0021 - val_loss: 0.0021

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
tf.keras.models.save_model(autoencoder, 'Model/model_poisson-1.h5')

# %%
autoencoder = tf.keras.models.load_model('Model/model_poisson-1.h5')

# %% [markdown]
# ## TEST THE MODEL

# %%
X_test_decoded = autoencoder(X_test_noisy)

# %%
n = 10
plt.figure(figsize=(20, 8))
for i in range(n):
    ii = np.random.randint(0, 80);
    # display original + noise
    ax = plt.subplot(3, n, i + 1)
    plt.title("noisy")
    plt.imshow(tf.squeeze(X_test_noisy[ii]))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # display reconstruction
    bx = plt.subplot(3, n, i + n + 1)
    plt.title("reconstructed")
    plt.imshow(tf.squeeze(X_test_decoded[ii]))
    plt.gray()
    bx.get_xaxis().set_visible(False)
    bx.get_yaxis().set_visible(False)

    # display original
    cx = plt.subplot(3, n, i + 2*n + 1)
    plt.title("original")
    plt.imshow(tf.squeeze(X_test[ii]))
    plt.gray()
    cx.get_xaxis().set_visible(False)
    cx.get_yaxis().set_visible(False)


plt.show()

# %%
n = 10
plt.figure(figsize=(20, 8))
for i in range(n):
    ii = np.random.randint(0, 80);
    # display original + noise
    ax = plt.subplot(3, n, i + 1)
    plt.title("noisy")
    plt.imshow(tf.squeeze(X_test_noisy[ii]))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # display reconstruction
    bx = plt.subplot(3, n, i + n + 1)
    plt.title("reconstructed")
    plt.imshow(tf.squeeze(X_test_decoded[ii]))
    plt.gray()
    bx.get_xaxis().set_visible(False)
    bx.get_yaxis().set_visible(False)

    # display original
    cx = plt.subplot(3, n, i + 2*n + 1)
    plt.title("original")
    plt.imshow(tf.squeeze(X_test[ii]))
    plt.gray()
    cx.get_xaxis().set_visible(False)
    cx.get_yaxis().set_visible(False)


plt.show()

# %% [markdown]
# ## PERFORM MEDIAN FILTERING

# %%
X_test_median = np.zeros_like(X_test_noisy)
for i in range(X_test.shape[0]):
    X_test_median[i] = median_filter(np.array(X_test_noisy[i]), size=3)

# %%
X_test_median.shape
# Out:
# (80, 128, 128, 1)

# %% [markdown]
# ## COMPARE PERFORMANCES

# %%
ssim_avg_noisy = []
ssim_avg_median = []
ssim_avg_reconstructed = []
for i in range(X_test.shape[0]):
    ssim_avg_noisy.append(structural_similarity(np.array(X_test[i]), np.array(X_test_noisy[i]), data_range=1, multichannel=True))
    ssim_avg_reconstructed.append(structural_similarity(np.array(X_test[i]), np.array(X_test_decoded[i]), data_range=1, multichannel=True))
    ssim_avg_median.append(structural_similarity(np.array(X_test[i]), np.array(X_test_median[i]), data_range=1, multichannel=True))
print("Structural similarity between Original and Noisy Image - " + str(np.mean(ssim_avg_noisy)))
print("Sructural similiarity between Original and Reconstructed Image - " + str(np.mean(ssim_avg_reconstructed)))
print("Sructural similiarity between Original and Median-filtered Image - " + str(np.mean(ssim_avg_median)))
# Out:
# Structural similarity between Original and Noisy Image - 0.2511757933832974
# Sructural similiarity between Original and Reconstructed Image - 0.8427829844696471
# Sructural similiarity between Original and Median-filtered Image - 0.42838644736693077
